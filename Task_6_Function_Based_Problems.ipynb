# %% [markdown]
# ### Problem 1 — Smart Parking Lot Management System
#
# This function calculates current parked vehicles from entry/exit logs
# and checks whether parking is available or full.

# %%
def parking_system(capacity, logs):
    parked = 0
    peak = 0

    for log in logs:
        if log == "IN":
            parked += 1
        elif log == "OUT":
            parked -= 1

        if parked > peak:
            peak = parked

    print("Currently Parked Vehicles:", parked)

    if parked > capacity:
        print("Parking Status: Full")
    else:
        print("Parking Status: Available")


parking_system(50, ["IN","IN","IN","OUT","IN","IN","OUT"])
# Out:
# Currently Parked Vehicles: 3
# Parking Status: Available

# %% [markdown]
# ### Problem 2 — Online Food Delivery Time Estimator
#
# This function estimates delivery time based on distance,
# traffic, and weather conditions.

# %%
def delivery_time(distance, traffic, weather):
    time = distance * 5  # base time

    if traffic == "High":
        time += 10
    if weather == "Rainy":
        time += 5

    print("Estimated Delivery Time:", time, "minutes")


delivery_time(8, "High", "Rainy")
# Out:
# Estimated Delivery Time: 55 minutes

# %% [markdown]
# ### Problem 3 — Movie Theatre Seat Occupancy Analyzer
#
# Calculates occupancy percentage and show status.

# %%
def theatre_occupancy(total_seats, booked_seats):
    occupancy = (len(booked_seats) / total_seats) * 100
    print("Occupancy:", occupancy, "%")

    if occupancy >= 100:
        print("Show Status: Housefull")
    elif occupancy >= 75:
        print("Show Status: Almost Full")
    else:
        print("Show Status: Available")


theatre_occupancy(200, [1]*150)
# Out:
# Occupancy: 75.0 %
# Show Status: Almost Full

# %% [markdown]
# ### Problem 4 — Cloud Server Load Classification
#
# Calculates average CPU load and classifies status.

# %%
def server_load(cpu_readings):
    avg = sum(cpu_readings) / len(cpu_readings)
    print("Average CPU Load:", avg, "%")

    if avg < 50:
        print("Server Status: Normal")
    elif avg <= 80:
        print("Server Status: Warning")
    else:
        print("Server Status: Critical")


server_load([45,60,70,85,90])
# Out:
# Average CPU Load: 70.0 %
# Server Status: Warning

# %% [markdown]
# ### Problem 5 — Smart Classroom Resource Usage Monitor
#
# Checks resource usage and alerts if any resource exceeds limit.

# %%
def resource_monitor(resources):
    overused = []

    for resource, hours in resources.items():
        if hours > 8:
            overused.append(resource)

    print("Overused Resources:", ", ".join(overused))
    print("Energy Alert:", "Yes" if overused else "No")


resource_monitor({"Projector":6,"AC":9,"Lights":4})
# Out:
# Overused Resources: AC
# Energy Alert: Yes

# %% [markdown]
# ### Problem 6 — Online Event Registration Capacity Controller
#
# Tracks registrations and handles waitlist.

# %%
def event_registration(capacity, registrations):
    if registrations <= capacity:
        confirmed = registrations
        waitlist = 0
        status = "Open"
    else:
        confirmed = capacity
        waitlist = registrations - capacity
        status = "Closed"

    print("Confirmed Registrations:", confirmed)
    print("Waitlisted Users:", waitlist)
    print("Registration Status:", status)


event_registration(100, 105)
# Out:
# Confirmed Registrations: 100
# Waitlisted Users: 5
# Registration Status: Closed
